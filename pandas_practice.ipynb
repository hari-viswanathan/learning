# %%
import sys
print(sys.version)
# Out:
# 3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:14:58)
# [Clang 12.0.5 (clang-1205.0.22.9)]

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Bob': ['I liked it', 'It was awful'], 'Alice': ['It was OK', 'Meh']}, index=['Product 1', 'Product 2'])

# %%
df
# Out:
#                     Bob      Alice
# Product 1    I liked it  It was OK
# Product 2  It was awful        Meh

# %%
df.Alice
# Out:
# Product 1    It was OK
# Product 2          Meh
# Name: Alice, dtype: object

# %%
df['Alice']
# Out:
# Product 1    It was OK
# Product 2          Meh
# Name: Alice, dtype: object

# %%
some_series = pd.Series([30, 40, 50], index=['Product 1', 'Product 2', 'Product 3'], name='Sales Numbers')

# %%
some_series
# Out:
# Product 1    30
# Product 2    40
# Product 3    50
# Name: Sales Numbers, dtype: int64

# %%
wine_reviews = pd.read_csv('./datasets/winemag-data-130k-v2.csv')

# %%
wine_reviews.shape
# Out:
# (129971, 14)

# %%
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
wine_reviews.tail()
# Out:
#         Unnamed: 0  country  \
# 129966      129966  Germany
# 129967      129967       US
# 129968      129968   France
# 129969      129969   France
# 129970      129970   France
#
#                                               description  \
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
# ...

# %%
wine_reviews.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
wine_reviews = pd.read_csv('./datasets/winemag-data-130k-v2.csv', index_col=0)

# %%
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wine_reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
wine_reviews.shape
# Out:
# (129971, 13)

# %%
pd.read_csv
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePathOrBuffer', sep=<no_default>, delimiter=None, header='infer', names=<no_default>, index_col=None, usecols=None, squeeze=False, prefix=<no_default>, mangle_dupe_cols=True, dtype: 'DtypeArg | None' = None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: 'str' = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, encoding_errors: 'str | None' = 'strict', dialect=None, error_bad_lines=None, warn_bad_lines=None, on_bad_lines=None, delim_whitespace=False, low_memory=True, memory_map=Fals
# ...

# %%
pd.set_option('max_rows', 5)

# %%
wine_reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
from learntools.core import binder; binder.bind(globals())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/jm/_0h7vnl51vs35yh3qwy5_r5w0000gn/T/ipykernel_74129/2066427994.py in <module>
# ----> 1 from learntools.core import binder; binder.bind(globals())
#
# ModuleNotFoundError: No module named 'learntools'

# %%
fruits = pd.DataFrame([[30, 21]])

# %%
fruits
# Out:
#     0   1
# 0  30  21

# %%
fruits.columns = ['Apples', 'Bananas']

# %%
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %%
fruits = pd.DataFrame([30, 21])

# %%
fruits
# Out:
#     0
# 0  30
# 1  21

# %%
fruits.columns = ['Apples']

# %%
fruits
# Out:
#    Apples
# 0      30
# 1      21

# %%
pd.to_csv
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/jm/_0h7vnl51vs35yh3qwy5_r5w0000gn/T/ipykernel_74129/3791268239.py in <module>
# ----> 1 pd.to_csv
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
wine_reviews.shape
# Out:
# (129971, 13)

# %%
wine_reviews.country
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews['country']
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews.country[0]
# Out:
# 'Italy'

# %%
wine_reviews['country'][0]
# Out:
# 'Italy'

# %%
reviews = wine_reviews

# %%
reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews.iloc[:, 0]
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
ex = [[1, 2, 3], [4, 5, 6]]

# %%
ex
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
ex[0]
# Out:
# [1, 2, 3]

# %%
ex[1]
# Out:
# [4, 5, 6]

# %%
ex[0][1]
# Out:
# 2

# %%
ex[1][0]
# Out:
# 4

# %%
reviews.iloc[1:4, 0]
# Out:
# 1    Portugal
# 2          US
# 3          US
# Name: country, dtype: object

# %%
reviews.iloc[[1, 100, 200], [0,1]]
# Out:
#       country                                        description
# 1    Portugal  This is ripe and fruity, a wine that is smooth...
# 100        US  Fresh apple, lemon and pear flavors are accent...
# 200     Italy  Aromas of mature black-skinned berry, tobacco ...

# %%
reviews.iloc[-5:, 0]
# Out:
# 129966    Germany
# 129967         US
# 129968     France
# 129969     France
# 129970     France
# Name: country, dtype: object

# %%
reviews.loc[0, 'country']
# Out:
# 'Italy'

# %%
reviews.iloc[:, [8,9,10]]
# Out:
#           taster_name taster_twitter_handle  \
# 0       Kerin O’Keefe          @kerinokeefe
# 1          Roger Voss            @vossroger
# ...               ...                   ...
# 129969     Roger Voss            @vossroger
# 129970     Roger Voss            @vossroger
#
#                                                     title
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)
# ...                                                   ...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
# [129971 rows x 3 columns]

# %%
reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'title']]
# Out:
#           taster_name taster_twitter_handle  \
# 0       Kerin O’Keefe          @kerinokeefe
# 1          Roger Voss            @vossroger
# ...               ...                   ...
# 129969     Roger Voss            @vossroger
# 129970     Roger Voss            @vossroger
#
#                                                     title
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)
# ...                                                   ...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
# [129971 rows x 3 columns]

# %% [raw]
# reviews

# %%
reviews.set_index('title')
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# ...                                                      ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...                                                                                               ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)       A dry style of Pinot Gris, this is crisp with ...
# ...

# %%
reviews.loc[0, 'country']
# Out:
# 'Italy'

# %%
reviews.idxmax
# Out:
# <bound method DataFrame.idxmax of          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.iloc[0, 0]
# Out:
# 'Italy'

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.set_index('title')
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# ...                                                      ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...                                                                                               ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)       A dry style of Pinot Gris, this is crisp with ...
# ...

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
new_reviews = reviews.set_index('title')

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
new_reviews
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# ...                                                      ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...                                                                                               ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)       A dry style of Pinot Gris, this is crisp with ...
# ...

# %%
new_reviews.loc['Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caroline Gewurztraminer (Alsace)', 'country']
# Out:
# 'France'

# %% [raw]
# reviews.loc[reviews.country == 'Italy']

# %%
reviews.loc[reviews.country == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews[reviews.country == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews[(reviews.country == 'Italy') & (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province region_1  \
# 120           Bricco Rocche Prapó      92   70.0           Piedmont   Barolo
# 130         Bricco Rocche Brunate      91   70.0           Piedmont   Barolo
# ...                           ...     ...    ...                ...      ...
# 129961                        NaN      90   30.0  Sicily & Sardinia  Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia  Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews[(reviews.country == 'Italy') | (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.loc[(reviews.country == 'Italy') | (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews[reviews.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province  \
# 1                            Avidagos      87   15.0    Douro
# 2                                 NaN      87   14.0   Oregon
# ...                               ...     ...    ...      ...
# 129969                            NaN      90   32.0   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#                  region_1           region_2   taster_name  \
# 1                     NaN                NaN    Roger Voss
# 2       Willamette Valley  Willamette Valley  Paul Gregutt
# ...

# %%
reviews.shape
# Out:
# (129971, 13)

# %%
reviews.loc[reviews.country.isin(['Australia'])]
# Out:
#           country                                        description  \
# 77      Australia  This medium-bodied Chardonnay features aromas ...
# 83      Australia  Pale copper in hue, this wine exudes passion f...
# ...           ...                                                ...
# 129447  Australia  This win is dense and dusty, with ripe ripe re...
# 129726  Australia  Hints of buttered toast and roasted nuts mark ...
#
#                      designation  points  price         province  \
# 77      Made With Organic Grapes      86   18.0  South Australia
# 83             Jester Sangiovese      86   20.0  South Australia
# ...                          ...     ...    ...              ...
# 129447                The Gaffer      87   26.0  South Australia
# 129726                     Croft      90   55.0  South Australia
#
#                region_1 region_2     taster_name taster_twitter_handle  \
# 77      South Australia      NaN  Joe Czerwinski                @JoeCz
# ...

# %%
reviews[reviews.country == 'Australia']['critic'] = 'someone'
# Out:
# /var/folders/jm/_0h7vnl51vs35yh3qwy5_r5w0000gn/T/ipykernel_74129/3803236606.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews[reviews.country == 'Australia']['critic'] = 'someone'

# %%
reviews.loc[reviews.country == 'Australia', 'critic'] = 'someone'

# %%
reviews[reviews.country == 'Australia']['critic']
# Out:
# 77        someone
# 83        someone
#            ...
# 129447    someone
# 129726    someone
# Name: critic, Length: 2329, dtype: object

# %%
reviews.loc[reviews.country == 'Australia', 'critic']
# Out:
# 77        someone
# 83        someone
#            ...
# 129447    someone
# 129726    someone
# Name: critic, Length: 2329, dtype: object

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)

# %%
reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery', 'critic', 'index_backwards'],
#       dtype='object')

# %%
reviews.new_index_backwards = range(len(reviews), 0, -1)
# Out:
# /var/folders/jm/_0h7vnl51vs35yh3qwy5_r5w0000gn/T/ipykernel_74129/1756358798.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   reviews.new_index_backwards = range(len(reviews), 0, -1)

# %%
import numpy as np

# %%
pd.set_option('max_rows', 10)

# %%
reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
reviews.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
reviews.taster_name.hist()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
reviews.taster_name.hist()
# Out:
# <AxesSubplot:>

# %%
reviews.taster_name.hist()
# Out:
# <AxesSubplot:>

# %%
reviews.points.mean()
# Out:
# 88.44713820775404

# %%
len(reviews.country.unique())
# Out:
# 44

# %% [raw]
# reviews.country.top()

# %%
reviews.taster_name.value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
#                       ...
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, Length: 19, dtype: int64

# %%
reviews.country.value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
#                           ...
# Bosnia and Herzegovina        2
# Armenia                       2
# Slovakia                      1
# China                         1
# Egypt                         1
# Name: country, Length: 43, dtype: int64

# %%
reviews.points.hist()
# Out:
# <AxesSubplot:>

# %%
reviews.country.value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
#                           ...
# Bosnia and Herzegovina        2
# Armenia                       2
# Slovakia                      1
# China                         1
# Egypt                         1
# Name: country, Length: 43, dtype: int64

# %%
reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
reviews = wine_reviews

# %%
mean = reviews.points.mean()

# %%
std = reviews.points.std()

# %%
reviews.points.map(lambda p: (p - mean)/std)
# Out:
# 0        -0.476075
# 1        -0.476075
# 2        -0.476075
# 3        -0.476075
# 4        -0.476075
#             ...
# 129966    0.510855
# 129967    0.510855
# 129968    0.510855
# 129969    0.510855
# 129970    0.510855
# Name: points, Length: 129971, dtype: float64

# %%
reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
def standardize_points(row):
    row.points = (row.points - mean)/std
    return row

# %%
reviews.points
# Out:
# 0         87
# 1         87
# 2         87
# 3         87
# 4         87
#           ..
# 129966    90
# 129967    90
# 129968    90
# 129969    90
# 129970    90
# Name: points, Length: 129971, dtype: int64

# %%
reviews.points.apply(standardize_points, axis='columns')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jm/_0h7vnl51vs35yh3qwy5_r5w0000gn/T/ipykernel_76620/105620606.py in <module>
# ----> 1 reviews.points.apply(standardize_points, axis='columns')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ...

# %%
review_points_mean = mean

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

reviews.apply(remean_points, axis='columns')
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation    points  price  \
# 0                                 Vulkà Bianco -1.447138    NaN
# ...

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
reviews.points.median()
# Out:
# 88.0

# %%
(reviews.points/reviews.price).max()
# Out:
# 21.5

# %%
reviews.loc[(reviews.points/reviews.price).argmax(), 'title']
# Out:
# 'Bandit NV Merlot (California)'

# %%
reviews.description.where('fruity' in reviews.description)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/jm/_0h7vnl51vs35yh3qwy5_r5w0000gn/T/ipykernel_76620/2852882395.py in <module>
# ----> 1 reviews.description.where('fruity' in reviews.description)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/series.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    5445         try_cast=lib.no_default,
#    5446     ):
# -> 5447         return super().where(cond, other, inplace, axis, level, errors, try_cast)
#    5448
# ...

# %%
reviews.points.sum()
# Out:
# 11495563

# %%
fruity_sum = reviews.description.map(lambda d: 'fruity' in d).sum()

# %%
tropical_sum = reviews.description.map(lambda d: 'tropical' in d).sum()

# %%
descriptor_counts = pd.Series([tropical_sum, fruity_sum], index=['tropical', 'fruity'])

# %%
descriptor_counts
# Out:
# tropical    3607
# fruity      9090
# dtype: int64

# %%
def convert_ratings(row):
    if row.country == 'Canada':
        return 3
    elif row.points >= 95:
        return 3
    elif row.points >= 85:
        return 2
    else:
        return 1
    
star_ratings = reviews.apply(convert_ratings, axis='columns')

# %%
star_ratings.describe()
# Out:
# count    129971.000000
# mean          1.924999
# std           0.332429
# min           1.000000
# 25%           2.000000
# 50%           2.000000
# 75%           2.000000
# max           3.000000
# dtype: float64

# %%
star_ratings.hist()
# Out:
# <AxesSubplot:>

# %%
reviews.groupby('points')

# %%
reviews.groupby('points').points

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80       397
# 81       692
# 82      1836
# 83      3025
# 84      6480
# 85      9530
# 86     12600
# 87     16933
# 88     17207
# 89     12226
# 90     15410
# 91     11359
# 92      9613
# 93      6489
# 94      3758
# 95      1535
# 96       523
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
reviews.loc[reviews.groupby('points').price.idxmin(), 'title']
# Out:
# 23437         Terrenal 2013 Estate Bottled Malbec (Mendoza)
# 33381     Viña Decana 2010 Crianza Tempranillo (Utiel-Re...
# 117303    Felix Solis 2012 Flirty Bird White (Vino de la...
# 59507       Pam's Cuties NV Unoaked Chardonnay (California)
# 29553             Broke Ass 2009 Red Malbec-Syrah (Mendoza)
# 1987      Felix Solis 2013 Flirty Bird Syrah (Vino de la...
# 64590                         Bandit NV Merlot (California)
# 24592     In Situ 2008 Reserva Sauvignon Blanc (Aconcagu...
# 44054      Ste. Chapelle 2001 Johannisberg Riesling (Idaho)
# 42891      Borsao 2008 Monte Oton Garnacha (Campo de Borja)
# 5145             Esser Cellars 2001 Chardonnay (California)
# 34629     Herdade dos Machados 2012 Toutalga Red (Alente...
# 29236     Aveleda 2011 Follies Fonte Nossa Senhora da Va...
# 68720     Château d'Aydie 2010 Aydie l'Origine Tannat-Ca...
# 23974            Quinta dos Murças 2011 Assobio Red (Douro)
# 5011      Dunham 2010 Lewis Estate Vineyard Riesling (Co...
# ...

# %%
len(reviews.points.values)
# Out:
# 129971

# %%
reviews.loc[reviews.groupby(['country', 'province']).points.idxmax()]
# Out:
#          country                                        description  \
# 82754  Argentina  If the color doesn't tell the full story, the ...
# 78303  Argentina  Take note, this could be the best wine Colomé ...
# 66146    Armenia  Deep salmon in color, this wine offers a bouqu...
# 37882  Australia  Writes the book on how to make a wine filled w...
# 85337  Australia  De Bortoli's Noble One is as good as ever in 2...
# ...          ...                                                ...
# 9133     Uruguay  This mature Bordeaux-style blend is earthy on ...
# 15750    Uruguay  A rich, heady bouquet offers aromas of blackbe...
# 93103    Uruguay  Rusty in color but deep and complex in nature,...
# 39898    Uruguay  Baked, sweet, heavy aromas turn earthy with ti...
# 39361    Uruguay  Cherry and berry aromas are ripe, healthy and ...
#
#                                    designation  points  price  \
# 82754                         Nicasia Vineyard      97  120.0
# ...

# %%
reviews.groupby('winery').apply(lambda d: d.iloc[0].title)
# Out:
# winery
# 1+1=3                                     1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                            10 Knots 2010 Viognier (Paso Robles)
# 100 Percent Wine              100 Percent Wine 2015 Moscato (California)
# 1000 Stories           1000 Stories 2013 Bourbon Barrel Aged Zinfande...
# 1070 Green                  1070 Green 2011 Sauvignon Blanc (Rutherford)
#                                              ...
# Órale                       Órale 2011 Cabronita Red (Santa Ynez Valley)
# Öko                    Öko 2013 Made With Organically Grown Grapes Ma...
# Ökonomierat Rebholz    Ökonomierat Rebholz 2007 Von Rotliegenden Spät...
# àMaurice               àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                                    Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
reviews.groupby('country').points.agg([len, min, max])
# Out:
#                           len  min  max
# country
# Argentina                3800   80   97
# Armenia                     2   87   88
# Australia                2329   80  100
# Austria                  3345   82   98
# Bosnia and Herzegovina      2   85   88
# Brazil                     52   80   89
# Bulgaria                  141   80   91
# Canada                    257   82   94
# Chile                    4472   80   95
# China                       1   89   89
# Croatia                    73   81   91
# Cyprus                     11   85   89
# Czech Republic             12   84   89
# Egypt                       1   84   84
# England                    74   89   95
# France                  22093   80  100
# Georgia                    86   82   92
# Germany                  2165   81   98
# Greece                    466   82   93
# Hungary                   146   81   97
# India                       9   87   93
# Israel                    505   80   94
# ...

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])

# %%
countries_reviewed.index
# Out:
# MultiIndex([('Argentina',  'Mendoza Province'),
#             ('Argentina',             'Other'),
#             (  'Armenia',           'Armenia'),
#             ('Australia',   'Australia Other'),
#             ('Australia',   'New South Wales'),
#             ('Australia',   'South Australia'),
#             ('Australia',          'Tasmania'),
#             ('Australia',          'Victoria'),
#             ('Australia', 'Western Australia'),
#             (  'Austria',           'Austria'),
#             ...
#             (       'US',        'Washington'),
#             (       'US', 'Washington-Oregon'),
#             (  'Ukraine',           'Ukraine'),
#             (  'Uruguay',         'Atlantida'),
#             (  'Uruguay',         'Canelones'),
#             (  'Uruguay',           'Juanico'),
#             (  'Uruguay',        'Montevideo'),
#             (  'Uruguay',          'Progreso'),
#             (  'Uruguay',          'San Jose'),
# ...

# %%
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# Armenia   Armenia              2
# Australia Australia Other    245
#           New South Wales     85
# ...                          ...
# Uruguay   Juanico             12
#           Montevideo          11
#           Progreso            11
#           San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# 3    Australia   Australia Other   245
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 420    Uruguay           Juanico    12
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed = countries_reviewed.reset_index()

# %%
countries_reviewed
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# 3    Australia   Australia Other   245
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 420    Uruguay           Juanico    12
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# 3    Australia   Australia Other   245
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 420    Uruguay           Juanico    12
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by='len')
# Out:
#           country               province    len
# 179        Greece  Muscat of Kefallonian      1
# 192        Greece          Sterea Ellada      1
# 194        Greece                 Thraki      1
# 354  South Africa             Paardeberg      1
# 40         Brazil       Serra do Sudeste      1
# ..            ...                    ...    ...
# 409            US                 Oregon   5373
# 227         Italy                Tuscany   5897
# 118        France               Bordeaux   5941
# 415            US             Washington   8639
# 392            US             California  36247
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#           country         province    len
# 392            US       California  36247
# 415            US       Washington   8639
# 118        France         Bordeaux   5941
# 227         Italy          Tuscany   5897
# 409            US           Oregon   5373
# ..            ...              ...    ...
# 101       Croatia              Krk      1
# 247   New Zealand        Gladstone      1
# 357  South Africa  Piekenierskloof      1
# 63          Chile          Coelemu      1
# 149        Greece           Beotia      1
#
# [425 rows x 3 columns]

# %%
countries_reviewed
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# 3    Australia   Australia Other   245
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 420    Uruguay           Juanico    12
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by=['country', 'len'])
# Out:
#        country          province   len
# 1    Argentina             Other   536
# 0    Argentina  Mendoza Province  3264
# 2      Armenia           Armenia     2
# 6    Australia          Tasmania    42
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 420    Uruguay           Juanico    12
# 424    Uruguay           Uruguay    24
# 419    Uruguay         Canelones    43
#
# [425 rows x 3 columns]

# %%
reviews_written = reviews.groupby('taster_twitter_handle').description.agg([len]).len

# %%
reviews_written
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# Name: len, dtype: int64

# %%
type(reviews_written)
# Out:
# pandas.core.frame.DataFrame

# %%
reviews_written = reviews.groupby('taster_twitter_handle').size()

# %%
reviews_written
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# dtype: int64

# %%
reviews_written = reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()

# %%
reviews_written
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# Name: taster_twitter_handle, dtype: int64

# %%
pd.Series(reviews.groupby('price').points.max(), index=reviews.groupby('price').price.unique())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'numpy.ndarray'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'numpy.ndarray'
# price
# [4.0]       86
# [5.0]       87
# [6.0]       88
# [7.0]       91
# [8.0]       91
#             ..
# [1900.0]    98
# [2000.0]    97
# [2013.0]    91
# [2500.0]    96
# [3300.0]    88
# Name: points, Length: 390, dtype: int64

# %%
best_rating_per_price = reviews.groupby('price').points.max().sort_index()

# %%
best_rating_per_price
# Out:
# price
# 4.0       86
# 5.0       87
# 6.0       88
# 7.0       91
# 8.0       91
#           ..
# 1900.0    98
# 2000.0    97
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
price_extremes = reviews.groupby('variety').price.agg([min, max])

# %%
price_extremes
# Out:
#               min    max
# variety
# Abouriou     15.0   75.0
# Agiorgitiko  10.0   66.0
# Aglianico     6.0  180.0
# Aidani       27.0   27.0
# Airen         8.0   10.0
# ...           ...    ...
# Zinfandel     5.0  100.0
# Zlahtina     13.0   16.0
# Zweigelt      9.0   70.0
# Çalkarası    19.0   19.0
# Žilavka      15.0   15.0
#
# [707 rows x 2 columns]

# %%
sorted_varieties = price_extremes.sort_values(by=['min', 'max'], ascending=False)

# %%
sorted_varieties
# Out:
#                                   min    max
# variety
# Ramisco                         495.0  495.0
# Terrantez                       236.0  236.0
# Francisa                        160.0  160.0
# Rosenmuskateller                150.0  150.0
# Tinta Negra Mole                112.0  112.0
# ...                               ...    ...
# Roscetto                          NaN    NaN
# Sauvignon Blanc-Sauvignon Gris    NaN    NaN
# Tempranillo-Malbec                NaN    NaN
# Vital                             NaN    NaN
# Zelen                             NaN    NaN
#
# [707 rows x 2 columns]

# %%
reviewer_mean_ratings = reviews.groupby('taster_name').points.mean()

# %%
reviewer_mean_ratings
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
# Anne Krebiehl MW      90.562551
# Carrie Dykes          86.395683
# Christina Pickard     87.833333
# Fiona Adams           86.888889
# Jeff Jenssen          88.319756
# Jim Gordon            88.626287
# Joe Czerwinski        88.536235
# Kerin O’Keefe         88.867947
# Lauren Buzzeo         87.739510
# Matt Kettmann         90.008686
# Michael Schachner     86.907493
# Mike DeSimone         89.101167
# Paul Gregutt          89.082564
# Roger Voss            88.708003
# Sean P. Sullivan      88.755739
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, dtype: float64

# %%
reviewer_mean_ratings.describe()
# Out:
# count    19.000000
# mean     88.233026
# std       1.243610
# min      85.855422
# 25%      87.323501
# 50%      88.536235
# 75%      88.975256
# max      90.562551
# Name: points, dtype: float64

# %%
country_variety_counts = reviews.groupby(['country', 'variety']).size().sort_values(ascending=False)

# %%
country_variety_counts
# Out:
# country  variety
# US       Pinot Noir                  9885
#          Cabernet Sauvignon          7315
#          Chardonnay                  6801
# France   Bordeaux-style Red Blend    4725
# Italy    Red Blend                   3624
#                                      ...
# Mexico   Cinsault                       1
#          Grenache                       1
#          Merlot                         1
#          Rosado                         1
# Uruguay  White Blend                    1
# Length: 1612, dtype: int64

# %%
type(country_variety_counts)
# Out:
# pandas.core.series.Series

# %%
reviews.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
type(reviews)
# Out:
# pandas.core.frame.DataFrame

# %%
reviews.price.dtype
# Out:
# dtype('float64')

# %%
type(reviews.price)
# Out:
# pandas.core.series.Series

# %%
reviews.points.dtypes
# Out:
# dtype('int64')

# %%
reviews.points.astype('float64')
# Out:
# 0         87.0
# 1         87.0
# 2         87.0
# 3         87.0
# 4         87.0
#           ...
# 129966    90.0
# 129967    90.0
# 129968    90.0
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float64

# %%
reviews.points
# Out:
# 0         87
# 1         87
# 2         87
# 3         87
# 4         87
#           ..
# 129966    90
# 129967    90
# 129968    90
# 129969    90
# 129970    90
# Name: points, Length: 129971, dtype: int64

# %%
reviews.loc[reviews.country.isnull()]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# 9750       NaN  This orange-style wine has a cloudy yellow-gol...
# ...        ...                                                ...
# 124176     NaN  This Swiss red blend is composed of four varie...
# 129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 913                     Asureti Valley      87   30.0      NaN      NaN
# ...

# %%
reviews[pd.notnull(reviews.country)]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
reviews.region_2.fillna('SomeValue')
# Out:
# 0                 SomeValue
# 1                 SomeValue
# 2         Willamette Valley
# 3                 SomeValue
# 4         Willamette Valley
#                 ...
# 129966            SomeValue
# 129967         Oregon Other
# 129968            SomeValue
# 129969            SomeValue
# 129970            SomeValue
# Name: region_2, Length: 129971, dtype: object

# %%
reviews.region_2.bfill()
# Out:
# 0         Willamette Valley
# 1         Willamette Valley
# 2         Willamette Valley
# 3         Willamette Valley
# 4         Willamette Valley
#                 ...
# 129966         Oregon Other
# 129967         Oregon Other
# 129968                  NaN
# 129969                  NaN
# 129970                  NaN
# Name: region_2, Length: 129971, dtype: object

# %%
reviews.region_2
# Out:
# 0                       NaN
# 1                       NaN
# 2         Willamette Valley
# 3                       NaN
# 4         Willamette Valley
#                 ...
# 129966                  NaN
# 129967         Oregon Other
# 129968                  NaN
# 129969                  NaN
# 129970                  NaN
# Name: region_2, Length: 129971, dtype: object

# %%
reviews.taster_twitter_handle.replace('@kerinokeefe', '@kerino')
# Out:
# 0             @kerino
# 1          @vossroger
# 2         @paulgwine
# 3                 NaN
# 4         @paulgwine
#              ...
# 129966            NaN
# 129967    @paulgwine
# 129968     @vossroger
# 129969     @vossroger
# 129970     @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
reviews.taster_twitter_handle
# Out:
# 0         @kerinokeefe
# 1           @vossroger
# 2          @paulgwine
# 3                  NaN
# 4          @paulgwine
#               ...
# 129966             NaN
# 129967     @paulgwine
# 129968      @vossroger
# 129969      @vossroger
# 129970      @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
reviews[reviews.region_1.isnull()] = 'Unknown'
reviews_per_region = reviews.region_1.value_counts().sort_values(ascending=False)
reviews_per_region
# Out:
# Unknown                 21247
# Napa Valley              4480
# Columbia Valley (WA)     4124
# Russian River Valley     3091
# California               2629
#                         ...
# Offida Rosso                1
# Corton Perrières            1
# Isle St. George             1
# Geelong                     1
# Paestum                     1
# Name: region_1, Length: 1230, dtype: int64

# %%
reviews.set_index('title')
# Out:
#                                                     country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                     Italy
# Unknown                                             Unknown
# Rainstorm 2013 Pinot Gris (Willamette Valley)            US
# St. Julian 2013 Reserve Late Harvest Riesling (...       US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...       US
# ...                                                     ...
# Unknown                                             Unknown
# Citation 2004 Pinot Noir (Oregon)                        US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)   France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)        France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...   France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# ...

# %%
reviews
# Out:
#         country                                        description  \
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1       Unknown                                            Unknown
# 2            US  Tart and snappy, the flavors of lime flesh and...
# 3            US  Pineapple rind, lemon pith and orange blossom ...
# 4            US  Much like the regular bottling from 2012, this...
# ...         ...                                                ...
# 129966  Unknown                                            Unknown
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                designation   points    price  \
# 0                             Vulkà Bianco       87      NaN
# ...

# %%
reviews.rename(columns={'points': 'scores'})
# Out:
#         country                                        description  \
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1       Unknown                                            Unknown
# 2            US  Tart and snappy, the flavors of lime flesh and...
# 3            US  Pineapple rind, lemon pith and orange blossom ...
# 4            US  Much like the regular bottling from 2012, this...
# ...         ...                                                ...
# 129966  Unknown                                            Unknown
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                designation   scores    price  \
# 0                             Vulkà Bianco       87      NaN
# ...

# %%
reviews.rename(index={0: 'First', 1: 'Second'})
# Out:
#         country                                        description  \
# First     Italy  Aromas include tropical fruit, broom, brimston...
# Second  Unknown                                            Unknown
# 2            US  Tart and snappy, the flavors of lime flesh and...
# 3            US  Pineapple rind, lemon pith and orange blossom ...
# 4            US  Much like the regular bottling from 2012, this...
# ...         ...                                                ...
# 129966  Unknown                                            Unknown
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                designation   points    price  \
# First                         Vulkà Bianco       87      NaN
# ...

# %%
reviews.columns.name

# %%
reviews.index.name

# %%
reviews.rename_axis('wines', axis='rows')
# Out:
#         country                                        description  \
# wines
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1       Unknown                                            Unknown
# 2            US  Tart and snappy, the flavors of lime flesh and...
# 3            US  Pineapple rind, lemon pith and orange blossom ...
# 4            US  Much like the regular bottling from 2012, this...
# ...         ...                                                ...
# 129966  Unknown                                            Unknown
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                designation   points    price  \
# wines
# 0                             Vulkà Bianco       87      NaN
# ...

# %%
reviews.index.name

# %%
reviews.rename_axis('wines', axis='rows').index.name
# Out:
# 'wines'
